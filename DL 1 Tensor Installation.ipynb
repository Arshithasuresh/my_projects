# %%
# !pip install virtualenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 16.7 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
import numpy as np
import pandas as pd

# be sure to change the file path
# if you have the dataset in another
# directly than the working folder
df = pd.read_csv('https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv')

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import tensorflow as tf

# 75% of the data is selected
train_df = df.sample(frac=0.75, random_state=4)

# it drops the training data
# from the original dataframe
val_df = df.drop(train_df.index)

# %%
# calling to (0,1) range
max_val = train_df.max(axis= 0)
min_val = train_df.min(axis= 0)

range = max_val - min_val
train_df = (train_df - min_val)/(range)

val_df = (val_df- min_val)/range

# %%
# now let's separate the targets and labels
X_train = train_df.drop('quality',axis=1)
X_val = val_df.drop('quality',axis=1)
y_train = train_df['quality']
y_val = val_df['quality']

# We'll need to pass the shape
# of features/inputs as an argument
# in our model, so let's define a variable
# to save it.
input_shape = [X_train.shape[1]]

input_shape
# Out:
# [11]

# %% [markdown]
# Steps to Build a Neural Network:
# 1. Import TensorFlow:
#
# Start by importing TensorFlow in your Python script or Jupyter Notebook.

# %%
import tensorflow as tf

# %% [markdown]
# 2. Prepare Data:
#
# Organize your data into training and testing sets.
# Normalize or preprocess the data if needed.
# Define the Model:
#
# 3. Create a sequential model using tf.keras.Sequential().
#
# Add layers to the model using model.add().
#
# Specify the input shape in the first layer.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=128, activation='relu', input_shape=(100,10)),
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(units= 20, activation='softmax')
])
""
# Out:
# ''

# %% [markdown]
# 4. Compile the Model:
#
# Specify the loss function, optimizer, and metrics.
#
# Common loss functions include 'sparse_categorical_crossentropy' for classification tasks.
#
# Common optimizers include 'adam', 'sgd', etc.

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 5. Train the Model:
#
# Use the fit() method to train the model on your training data.
#
# Specify the number of epochs (iterations) and batch size.

# %%
model.fit(train_data, train_labels, epochs=10, batch_size=32, validation_data=(val_data, val_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1845ff441667> in <cell line: 1>()
# ----> 1 model.fit(train_data, train_labels, epochs=10, batch_size=32, validation_data=(val_data, val_labels))
#
# NameError: name 'train_data' is not defined

# %% [markdown]
# 6. Evaluate the Model:
#
# Use the evaluate() method to evaluate the model on your test data.

# %%
test_loss, test_accuracy = model.evaluate(test_data, test_labels)
print(f'Test Accuracy: {test_accuracy}')

# %% [markdown]
# 7. Make Predictions:
#
# Use the trained model to make predictions on new data.

# %%
predictions = model.predict(new_data)

# %%
import tensorflow as tf
msg= tf.constant('hello')
tf.print(msg)
# Out:
# hello
