# %%
import nltk
import re

# %%
text= "This is a sample text. It contains multiple texts, with the symbols like ',' '?' '!' ."
tokenized_text=text.split('.')
tokenized_text1=text.split()
tokenized_text2=text.split(',')
tokenized_text3=text.split('?')
tokenized_text4=text.split('!')
print(tokenized_text)
print(tokenized_text1)
print(tokenized_text2)
print(tokenized_text3)
print(tokenized_text4)
# Out:
# ['This is a sample text', " It contains multiple texts, with the symbols like ',' '?' '!' ", '']
# ['This', 'is', 'a', 'sample', 'text.', 'It', 'contains', 'multiple', 'texts,', 'with', 'the', 'symbols', 'like', "','", "'?'", "'!'", '.']
# ['This is a sample text. It contains multiple texts', " with the symbols like '", "' '?' '!' ."]
# ["This is a sample text. It contains multiple texts, with the symbols like ',' '", "' '!' ."]
# ["This is a sample text. It contains multiple texts, with the symbols like ',' '?' '", "' ."]

# %%
text = """Founded in 2002, SpaceX’s mission is to enable humans? to become a spacefaring
civilization and a multi-planet species by building a self-sustaining city on Mars. In 2008,
SpaceX’s Falcon 1 became the first privately! developed liquid-fuel launch vehicle to orbit
the Earth."""

# %% [markdown]
# # ***Tokenization using split function***

# %% [markdown]
# text is splitted based on the given delimeter '.'

# %%
tokenized_text=text.split('.')
print(tokenized_text)
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable humans? to become a spacefaring\ncivilization and a multi-planet species by building a self-sustaining city on Mars', ' In 2008,\nSpaceX’s Falcon 1 became the first privately! developed liquid-fuel launch vehicle to orbit\nthe Earth', '']

# %% [markdown]
# text is splitted based on the whitespaces

# %%
tokenized_text1=text.split()
print(tokenized_text1)
# Out:
# ['Founded', 'in', '2002,', 'SpaceX’s', 'mission', 'is', 'to', 'enable', 'humans?', 'to', 'become', 'a', 'spacefaring', 'civilization', 'and', 'a', 'multi-planet', 'species', 'by', 'building', 'a', 'self-sustaining', 'city', 'on', 'Mars.', 'In', '2008,', 'SpaceX’s', 'Falcon', '1', 'became', 'the', 'first', 'privately!', 'developed', 'liquid-fuel', 'launch', 'vehicle', 'to', 'orbit', 'the', 'Earth.']

# %% [markdown]
# text is splitted based on the delimeter ','

# %%
tokenized_text2=text.split(',')
print(tokenized_text2)
# Out:
# ['Founded in 2002', ' SpaceX’s mission is to enable humans? to become a spacefaring\ncivilization and a multi-planet species by building a self-sustaining city on Mars. In 2008', '\nSpaceX’s Falcon 1 became the first privately! developed liquid-fuel launch vehicle to orbit\nthe Earth.']

# %% [markdown]
# text is splitted based on the delimeter '?'

# %%
tokenized_text3=text.split('?')
print(tokenized_text3)
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable humans', ' to become a spacefaring\ncivilization and a multi-planet species by building a self-sustaining city on Mars. In 2008,\nSpaceX’s Falcon 1 became the first privately! developed liquid-fuel launch vehicle to orbit\nthe Earth.']

# %% [markdown]
# text is splitted based on the delimeter '!'

# %%
tokenized_text4=text.split('!')
print(tokenized_text4)
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable humans? to become a spacefaring\ncivilization and a multi-planet species by building a self-sustaining city on Mars. In 2008,\nSpaceX’s Falcon 1 became the first privately', ' developed liquid-fuel launch vehicle to orbit\nthe Earth.']

# %% [markdown]
# # ***Tokenizaton using Regular expression***

# %%
sentences = re.compile('[.!?] ').split(text)
print(sentences)
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable humans', 'to become a spacefaring\ncivilization and a multi-planet species by building a self-sustaining city on Mars', 'In 2008,\nSpaceX’s Falcon 1 became the first privately', 'developed liquid-fuel launch vehicle to orbit\nthe Earth.']

# %% [markdown]
# # ***Tokenizaton using nltk library***

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Founded in 2002, SpaceX’s mission is to enable humans?', 'to become a spacefaring\ncivilization and a multi-planet species by building a self-sustaining city on Mars.', 'In 2008,\nSpaceX’s Falcon 1 became the first privately!', 'developed liquid-fuel launch vehicle to orbit\nthe Earth.']

# %% [markdown]
# # ***Word Tokenizaton using Regular Expression***

# %%
spaces = r"\s+"
print(re.split(spaces, text))
# Out:
# ['Founded', 'in', '2002,', 'SpaceX’s', 'mission', 'is', 'to', 'enable', 'humans?', 'to', 'become', 'a', 'spacefaring', 'civilization', 'and', 'a', 'multi-planet', 'species', 'by', 'building', 'a', 'self-sustaining', 'city', 'on', 'Mars.', 'In', '2008,', 'SpaceX’s', 'Falcon', '1', 'became', 'the', 'first', 'privately!', 'developed', 'liquid-fuel', 'launch', 'vehicle', 'to', 'orbit', 'the', 'Earth.']

# %% [markdown]
# # ***Word Tokenizaton***

# %%
from nltk.tokenize import word_tokenize
print(word_tokenize(text))
# Out:
# ['Founded', 'in', '2002', ',', 'SpaceX', '’', 's', 'mission', 'is', 'to', 'enable', 'humans', '?', 'to', 'become', 'a', 'spacefaring', 'civilization', 'and', 'a', 'multi-planet', 'species', 'by', 'building', 'a', 'self-sustaining', 'city', 'on', 'Mars', '.', 'In', '2008', ',', 'SpaceX', '’', 's', 'Falcon', '1', 'became', 'the', 'first', 'privately', '!', 'developed', 'liquid-fuel', 'launch', 'vehicle', 'to', 'orbit', 'the', 'Earth', '.']

# %% [markdown]
# # ***Stop word removal***

# %%
nltk.download('stopwords')
text = "This is an example text for stopword removal and filtering. This is done using NLTK's stopwords."
words = nltk.word_tokenize(text)
print("Unfiltered: ", words)
stopwords = nltk.corpus.stopwords.words("english")
cleaned = [word for word in words if word not in stopwords]
print("Filtered: ", cleaned)
# Out:
# Unfiltered:  ['This', 'is', 'an', 'example', 'text', 'for', 'stopword', 'removal', 'and', 'filtering', '.', 'This', 'is', 'done', 'using', 'NLTK', "'s", 'stopwords', '.']
# Filtered:  ['This', 'example', 'text', 'stopword', 'removal', 'filtering', '.', 'This', 'done', 'using', 'NLTK', "'s", 'stopwords', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import string
text = "This is an example text for stopword removal and filtering. This is done using NLTK's stopwords."
words = nltk.word_tokenize(text)
stopwords = nltk.corpus.stopwords.words("english")
# Extending the stopwords list
stopwords.extend(string.punctuation)
# Remove stop words and tokens with length < 2
cleaned = [word.lower() for word in words if (word not in stopwords) and len(word) > 2]
print(cleaned)
# Out:
# ['this', 'example', 'text', 'stopword', 'removal', 'filtering', 'this', 'done', 'using', 'nltk', 'stopwords']

# %%
Banned_List = ["idiot", "stupid", "donkey"]
sentence = "You are not only stupid , but also an idiot ."
def censor(sentence = ""):
   new_sentence = ""

   for word in sentence.split():
    print(word)
    if word in Banned_List:
      new_sentence += '* '
    else:
      new_sentence += word + ' '

   return new_sentence
print(censor(sentence))
# Out:
# You
# are
# not
# only
# stupid
# ,
# but
# also
# an
# idiot
# .
# You are not only * , but also an * .
