# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
# Generate sample data
X = np.random.randn(1000, 10) # Input features
y = np.random.choice([0, 1], size=(1000,), p=[0.8, 0.2]) # Target labels
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=42)
# Compute class weights to handle class imbalance
class_counts = np.bincount(y_train)
total_samples = len(y_train)
class_weights = {i: total_samples / count for i, count in enumerate(class_counts)}
# Convert the data into TensorFlow tensors
X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
X_test = tf.convert_to_tensor(X_test, dtype=tf.float32)
y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)
# Build the RNN model
model = tf.keras.Sequential()
model.add(tf.keras.layers.SimpleRNN(units=32, activation='relu', input_shape=(10, 1)))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Train the model
model.fit(X_train, y_train, class_weight=class_weights, epochs=10, batch_size=32)
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss:.4f}')
print(f'Test accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/10
# 25/25 [==============================] - 2s 4ms/step - loss: 1.4083 - accuracy: 0.4663
# Epoch 2/10
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3932 - accuracy: 0.5288
# Epoch 3/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3842 - accuracy: 0.5800
# Epoch 4/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3780 - accuracy: 0.5738
# Epoch 5/10
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3738 - accuracy: 0.5713
# Epoch 6/10
# 25/25 [==============================] - 0s 4ms/step - loss: 1.3714 - accuracy: 0.5675
# Epoch 7/10
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3682 - accuracy: 0.5813
# Epoch 8/10
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3638 - accuracy: 0.5713
# Epoch 9/10
# 25/25 [==============================] - 0s 5ms/step - loss: 1.3595 - accuracy: 0.5713
# Epoch 10/10
# ...
