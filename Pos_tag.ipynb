# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
sentence = "He was being opposed by her without any reason.\A plan is being prepared by charles for next project"
for sent in sent_tokenize(sentence):
  wordtokens = word_tokenize(sent)
  print(nltk.pos_tag(wordtokens),end='\n\n')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('He', 'PRP'), ('was', 'VBD'), ('being', 'VBG'), ('opposed', 'VBN'), ('by', 'IN'), ('her', 'PRP$'), ('without', 'IN'), ('any', 'DT'), ('reason.\\A', 'NN'), ('plan', 'NN'), ('is', 'VBZ'), ('being', 'VBG'), ('prepared', 'VBN'), ('by', 'IN'), ('charles', 'NNS'), ('for', 'IN'), ('next', 'JJ'), ('project', 'NN')]

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
sentence = "He was being opposed by her without any reason.\ A plan is being prepared by charles for next project"
for token in nlp(sentence):
 print(f'{token.text:{10}} {token.tag_:>{10}}\t{spacy.explain(token.tag_):<{50}} {token.pos_:>{5}} {spacy.explain(token.pos_):<{50}}')
# Out:
# He                PRP	pronoun, personal                                   PRON pronoun
# was               VBD	verb, past tense                                     AUX auxiliary
# being             VBG	verb, gerund or present participle                   AUX auxiliary
# opposed           VBN	verb, past participle                               VERB verb
# by                 IN	conjunction, subordinating or preposition            ADP adposition
# her               PRP	pronoun, personal                                   PRON pronoun
# without            IN	conjunction, subordinating or preposition            ADP adposition
# any                DT	determiner                                           DET determiner
# reason.\           NN	noun, singular or mass                              NOUN noun
# A                  DT	determiner                                           DET determiner
# plan               NN	noun, singular or mass                              NOUN noun
# ...

# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')
doc =nlp("He was being opposed by her without any reason.")
displacy.render(doc, style='dep')
for token in nlp(doc):
 print(f'{token.text:{10}} {token.tag_:>{10}}\t{spacy.explain(token.tag_):<{50}} {token.pos_:>{5}} {spacy.explain(token.pos_):<{50}}')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bcf409d41ee448d1abade6199b0c0bb9-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.chunk import RegexpParser

# Example sentence
text = "The Air India flight to Delhi was ready to board."

# Splitting the sentence into words
list_of_words = word_tokenize(text)

# Applying POS tagging
tagged_words = pos_tag(list_of_words)

# Define the chunking pattern
chunk_to_be_extracted = r'''Chunk: {<DT>*<NNP>*<NN>*}'''

# Applying chunking to the text
chunkParser = RegexpParser(chunk_to_be_extracted)
chunked_sentence = chunkParser.parse(tagged_words)

# Draw the chunked sentence (This will open a new window displaying the chunk tree)
chunked_sentence.draw()

# Print the obtained chunks
print('Chunks obtained: \n')
for subtree in chunked_sentence.subtrees():
    if subtree.label() == 'Chunk':
        print(subtree)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-10-b219d33b0b66> in <cell line: 22>()
#      20
#      21 # Draw the chunked sentence (This will open a new window displaying the chunk tree)
# ---> 22 chunked_sentence.draw()
#      23
#      24 # Print the obtained chunks
#
# /usr/local/lib/python3.10/dist-packages/nltk/tree/tree.py in draw(self)
#     759         from nltk.draw.tree import draw_trees
#     760
# --> 761         draw_trees(self)
#     762
#     763     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/nltk/draw/tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# /usr/local/lib/python3.10/dist-packages/nltk/draw/tree.py in __init__(self, *trees)
# ...
